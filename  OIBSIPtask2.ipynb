# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ----------- ------------------------- 92.2/293.3 kB 403.5 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/293.3 kB 403.5 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/293.3 kB 403.5 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/293.3 kB 403.5 kB/s eta 0:00:01
#      -------------------- --------------- 163.8/293.3 kB 364.0 kB/s eta 0:00:01
#      -------------------- --------------- 163.8/293.3 kB 364.0 kB/s eta 0:00:01
#      -------------------- --------------- 163.8/293.3 kB 364.0 kB/s eta 0:00:01
#      ------------------------- ---------- 204.8/293.3 kB 319.5 kB/s eta 0:00:01
#      ------------------------------ ----- 245.8/293.3 kB 359.0 kB/s eta 0:00:01
#      ------------------------------- ---- 256.0/293.3 kB 342.3 kB/s eta 0:00:01
#      -----------------------------------  286.7/293.3 kB 376.7 kB/s eta 0:00:01
#      ------------------------------------ 293.3/293.3 kB 362.4 kB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\sspmcoe\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns.values.tolist()
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['TV'], ax = axs[0])
plt1 = sns.boxplot(df['Newspaper'], ax = axs[1])
plt1 = sns.boxplot(df['Radio'], ax = axs[2])
plt.tight_layout()

# %%
sns.distplot(df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
iqr = df.Newspaper.quantile(0.75) - df.Newspaper.quantile(0.25)
lower_bridge = df["Newspaper"].quantile(0.25) - (iqr*1.5)
Upper_bridge = df["Newspaper"].quantile(0.75) + (iqr*1.5)
print(lower_bridge)
print(Upper_bridge)
# Out:
# -35.775000000000006
# 93.625

# %%
data = df.copy()
data.loc[data['Newspaper']>=93, 'Newspaper']=93
sns.boxplot(data['Newspaper'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['Sales'])
# Out:
# <Axes: >

# %%
sns.pairplot(data, x_vars=['TV','Newspaper','Radio'],
             y_vars='Sales', height=4, aspect=4, kind='scatter')
plt.show()

# %%
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
important_features = list(df.corr()['Sales'][(df.corr()['Sales']>+5)|(df.corr()['Sales']<-0.5)].index)
print(important_features)
# Out:
# []

# %%
x = data['TV']
y = data['Sales']
x = x.values.reshape(-1,1)
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
print(x.shape,y.shape)
# Out:
# (200, 1) (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33)
print(x_train.shape,y_train.shape)
# Out:
# (134, 1) (134,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
knn = KNeighborsRegressor().fit(x_train,y_train)
knn
KNeighborsRegressor()
knn_train_pred = knn.predict(x_train)
knn_test_pred = knn.predict(x_test)
print(knn_train_pred, knn_test_pred)
# Out:
# [ 9.8   5.96  9.86 17.46  5.96 12.78 20.14 11.98 10.74 19.1  20.2  12.54
#  17.3  18.32  5.96 16.74 14.8  11.1  16.44 15.16 20.54 17.3  15.64 11.28
#  11.72 14.42  8.08 15.42 17.3  16.62 10.74 12.48 15.46  9.8  17.46 15.46
#  14.8  11.74 11.28 19.98 17.   17.02 15.92  8.46 13.68  8.8  12.86 13.56
#  11.7  17.46 12.48 17.02 16.74 19.1  11.96 12.4  15.42 10.4  16.94 18.88
#  13.94 18.36 17.4   5.96  9.7  11.44  4.44 10.76 15.16 20.2  16.26 11.44
#  11.72 11.92 13.56 17.2  11.7   7.56 15.92 16.62 17.02 18.88 10.06 17.4
#  21.72  8.46 17.16 14.8  17.   15.6  14.42 19.74  4.44 19.74 12.4  19.98
#   9.8   6.06 17.   20.2  16.62 18.88  9.7   7.52 14.44  5.96 12.06 17.3
#   7.52 19.74 12.86 17.16 10.74  8.08 11.7  13.94 10.76 17.3  11.58 11.92
#  18.32 15.16  5.26 11.92  8.3  19.    9.64 12.86 10.46  8.3  11.44 16.74
#  12.86 11.92] [12.06  9.64 16.44 12.06 12.48 12.06 18.88 19.3   9.68  8.3  10.74 11.92
#  17.48  8.3  20.2  19.   11.74 12.42 10.08 20.2  14.48 16.62 17.3  11.7
#  18.88 13.68 12.86 17.46 11.72 15.64  7.52 15.16  8.46 16.24 12.86 17.46
#   9.86 10.52 16.62  7.56 10.76 20.2  12.1  15.16 13.68  8.08 12.12 10.46
#  11.1  14.8  19.   15.92 17.46 17.46 12.06 14.82  7.52 18.88 11.58 13.68
#  12.4   8.46 15.54  9.86 14.52 15.92]

# %%
Results = pd.DataFrame(columns=["Model","train R2","Test R2","Test RMSE","Varience"])

# %%
import statsmodels.api as sm
x_train_constant = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train_constant).fit()
model.params
# Out:
# const    7.012874
# x1       0.045459
# dtype: float64

# %%
Results.head()
# Out:
# Empty DataFrame
# Columns: [Model, train R2, Test R2, Test RMSE, Varience]
# Index: []

# %%
import statsmodels.api as sm
x_train_constant = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train_constant).fit()
model.params
# Out:
# const    7.012874
# x1       0.045459
# dtype: float64

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     201.7
# Date:                Mon, 14 Aug 2023   Prob (F-statistic):           2.34e-28
# Time:                        12:25:04   Log-Likelihood:                -345.61
# No. Observations:                 134   AIC:                             695.2
# Df Residuals:                     132   BIC:                             701.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0129      0.548     12.787      0.000       5.928       8.098
# x1             0.0455      0.003     14.200      0.000       0.039       0.052
# ==============================================================================
# Omnibus:                        0.047   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.977   Jarque-Bera (JB):                0.175
# Skew:                          -0.026   Prob(JB):                        0.916
# Kurtosis:                       2.831   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, 6.9955 + 0.0541*x_train,'y')

# %%
y_train_pred = model.predict(x_train_constant)
res = (y_train - y_train_pred)
res
# Out:
# 148    2.159683
# 132   -1.694730
# 1      1.364199
# 27    -2.027584
# 8     -2.603822
#          ...
# 172   -0.303871
# 65    -0.849546
# 104    2.858788
# 186   -3.054407
# 7      0.722952
# Name: Sales, Length: 134, dtype: float64

# %%
y_train_pred
# Out:
# array([ 8.74031695,  7.39473011,  9.03580054, 17.92758379,  7.40382192,
#        12.14519714, 18.30489362, 12.89527088, 10.05408247, 16.80474613,
#        20.22780993, 10.65868736, 19.08678867, 16.71382811,  7.3447252 ,
#        17.80484446, 16.09558551, 11.57695946, 16.59108877, 14.49088229,
#        18.62310672, 18.95495752, 14.97274785, 10.09499558, 12.99982661,
#        15.05911997,  8.09479894, 14.85455441, 19.06860506, 15.57735274,
#        11.28147586, 12.00427419, 16.29105927,  8.80850547, 18.00031822,
#        16.33197238, 16.09558551, 10.34956606, 10.12227099, 19.60047553,
#        15.99557567, 16.41379861, 17.44571824,  8.26299729, 13.81808888,
#         8.44483335, 13.43623315, 17.12295924, 11.090548  , 17.92758379,
#        12.00427419, 15.89556584, 17.80484446, 16.77292482, 11.76788732,
#        10.43593819, 14.80000359, 10.90871194, 15.23186423, 16.94112318,
#        17.19569366, 19.45500668, 15.41824619,  7.40836782,  8.96761202,
#        10.1586382 ,  7.0446957 , 11.43149061, 14.54088721, 20.32781976,
#        15.70009208, 10.22228082, 13.11802005, 12.28612008, 17.12295924,
#        17.56391168, 11.12236931,  7.60838748, 17.37752972, 17.0047658 ,
#        16.41834451, 20.01415256,  9.28582512, 15.41824619, 19.90505093,
#         8.17662517, 15.79555601, 16.05467239, 15.99557567, 17.89121658,
#        15.05911997, 18.32307722,  7.19925635, 18.41854115, 10.40866278,
#        19.59138373,  8.74940875,  7.54474486, 15.31369046, 20.18235092,
#        15.55462323, 16.86838875,  8.97215792,  7.79476944, 14.66817245,
#         7.36745471, 10.56776933, 18.96404933,  7.78113174, 18.55037229,
#        13.39077414, 15.81828552, 10.01771526,  8.14934976, 10.97690046,
#        17.27751989, 11.36330209, 18.8913149 , 13.20439218, 12.51341516,
#        16.71837401, 14.44542328,  7.25835307, 12.3406709 ,  7.86295796,
#        19.75049028,  9.62676773, 13.50896758,  9.844971  ,  7.90387108,
#        10.1495464 , 17.84121167, 13.35440693, 12.47704795])

# %%
fig = plt.figure()
sns.distplot(res,bins=15)
fig.suptitle('Error Terms', fontsize = 15)
plt.show()

# %%
plt.scatter(x_train, res)
plt.show()

# %%
x_test_constant = sm.add_constant(x_test)
y_pred = model.predict(x_test_constant)
y_pred
# Out:
# array([10.48139721,  9.56767101, 16.54108385, 10.48594311, 12.04518731,
#        10.44502999, 16.94566908, 16.85020515,  8.69031203,  7.86750387,
#        11.29511357, 12.49068565, 16.59563467,  7.89477928, 20.48692632,
#        19.77321979, 12.60887909, 11.89517256,  9.44493167, 20.35964107,
#        17.03658711, 15.55007733, 19.14588539, 11.02690538, 19.93687224,
#        13.70898724, 13.34076922, 18.06850674, 12.9725512 , 15.00002326,
#         7.79476944, 14.59543803,  8.31300221, 17.67301331, 13.34531512,
#        16.21832485,  9.04489234, 11.68151519, 17.02749531,  7.61293338,
#        11.3860316 , 20.08688699, 13.2816725 , 14.43633147, 13.8999151 ,
#         8.15389566, 12.72707253,  9.72223166, 11.44512831, 16.0637642 ,
#        19.8050411 , 17.47299365, 17.91394609, 17.91849199, 10.48594311,
#        14.13175608,  7.82659075, 16.90930187, 13.15893316, 13.82263478,
#        10.42684639,  8.23117598, 17.34116251,  9.2085448 , 14.74999867,
#        17.39116742])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import numpy as np

# Create an SVR model
svr_model = SVR(kernel='linear')  # You can choose different kernels and adjust hyperparameters

# Train the SVR model on the training data
svr_model.fit(x_train, y_train)

# Predict target values on the test data
svr_test_pred = svr_model.predict(x_test)

# Calculate RMSE for SVR predictions
rmse_svr = np.sqrt(mean_squared_error(y_test, svr_test_pred))

print("RMSE for SVR:", rmse_svr)
# Out:
# RMSE for SVR: 3.3494410112297417

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.6039770288305065

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, 6.9955 + 0.0541 * x_test,'y')
